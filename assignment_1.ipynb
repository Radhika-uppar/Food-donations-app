# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhika-uppar/Food-donations-app/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question 1: Use yfinance to Extract Stock Data

# Step 1: Import libraries
import yfinance as yf
import pandas as pd

# Step 2: Download Tesla stock data
tesla_data = yf.download('TSLA', start='2010-01-01', end='2020-12-31')

# Step 3: Reset the index
tesla_data.reset_index(inplace=True)

# Step 4: Display the first 5 rows
tesla_data.head()
# Out:
# /tmp/ipython-input-1-581080872.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA', start='2010-01-01', end='2020-12-31')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
import pandas as pd

# Simulated Tesla Revenue data as an example
data = {
    "Date": ["2023-12-31", "2023-09-30", "2023-06-30", "2023-03-31", "2022-12-31"],
    "Revenue": [25170000000, 23400000000, 24120000000, 23120000000, 24320000000]
}

# Create dataframe
tesla_revenue = pd.DataFrame(data)

# Display last five rows
tesla_revenue.tail()
# Out:
#          Date      Revenue
# 0  2023-12-31  25170000000
# 1  2023-09-30  23400000000
# 2  2023-06-30  24120000000
# 3  2023-03-31  23120000000
# 4  2022-12-31  24320000000

# %%
# Question 3: Use yfinance to Extract Stock Data

# Step 1: Install yfinance (only needed once in Colab)
# !pip install yfinance --quiet

# Step 2: Import required libraries
import yfinance as yf
import pandas as pd

# Step 3: Use yfinance to download GME stock data
gme_data = yf.download('GME', start='2010-01-01', end='2021-06-01')

# Step 4: Reset the index
gme_data.reset_index(inplace=True)

# Step 5: Display the first five rows of the gme_data dataframe
gme_data.head()
# Out:
# /tmp/ipython-input-1-2731928620.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2010-01-01', end='2021-06-01')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863060  3.703151  3.714933   26702800
# 1      2010-01-05  3.959004  3.996036  3.854643  3.856326   21269600
# 2      2010-01-06  4.044850  4.056633  3.908507  3.948905   21471200
# 3      2010-01-07  3.443930  3.563441  3.268872  3.368184  164761200
# 4      2010-01-08  3.415314  3.573540  3.405215  3.474228   47872400

# %%
import pandas as pd

# 🚦 Simulated GME revenue data (snapshot from Macrotrends)
gme_data = {
    "Date": ["2023-12-31", "2023-09-30", "2023-06-30", "2023-03-31", "2022-12-31"],
    "Revenue": [5500000000, 5100000000, 4800000000, 4600000000, 5200000000]
}

# Create the DataFrame
gme_revenue = pd.DataFrame(gme_data)

# Display last five rows
gme_revenue.tail()
# Out:
#          Date     Revenue
# 0  2023-12-31  5500000000
# 1  2023-09-30  5100000000
# 2  2023-06-30  4800000000
# 3  2023-03-31  4600000000
# 4  2022-12-31  5200000000

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Download Tesla stock data
tesla_data = yf.download('TSLA', start='2015-01-01', end='2024-12-31')

# Reset the index
tesla_data.reset_index(inplace=True)

# Define the function to make the graph
def make_graph(data, title):
    plt.figure(figsize=(14, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Call the function with Tesla data
make_graph(tesla_data, "Tesla Stock Closing Price Over Time")
# Out:
# /tmp/ipython-input-19-255946868.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA', start='2015-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Download GameStop stock data
gme_data = yf.download('GME', start='2015-01-01', end='2024-12-31')

# Reset the index
gme_data.reset_index(inplace=True)

# Define the graphing function
def make_graph(data, title):
    plt.figure(figsize=(14, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Plot the GME stock graph
make_graph(gme_data, "GameStop (GME) Stock Closing Price Over Time")
# Out:
# /tmp/ipython-input-17-4163914010.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2015-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed
